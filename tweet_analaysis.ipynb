# %% [markdown]
# ## Two plots to perform a sentiment analysis of the Twitter activity of various news outlets
#
# ### News organizations: BBC, CBS, CNN, Fox, and New York times.
#
#
# - The first plot will be and/or feature the following:
#
#
# Be a scatter plot of sentiments of the last 100 tweets sent out by each news organization, ranging from -1.0 to 1.0, where a score of 0 expresses a neutral sentiment, -1 the most negative sentiment possible, and +1 the most positive sentiment possible.
# Each plot point will reflect the compound sentiment of a tweet.
# Sort each plot point by its relative timestamp.
#
#
# - The second plot will be a bar plot visualizing the overall sentiments of the last 100 tweets from each organization. For this plot, you will again aggregate the compound sentiments analyzed by VADER.
#
# The tools of the trade you will need for your task as a data analyst include the following: tweepy, pandas, matplotlib, and VADER.
#
# Your final Jupyter notebook must:
#
# - Pull last 100 tweets from each outlet.
# - Perform a sentiment analysis with the compound, positive, neutral, and negative scoring for each tweet.
# - Pull into a DataFrame the tweet's source account, its text, its date, and its compound, positive, neutral, and negative sentiment scores.
# - Export the data in the DataFrame into a CSV file.
# - Save PNG images for each plot.
#
#
# ### Analysis on trends
#
# - Analysis 1
# - Analysis 2
# - Analysis 3

# %%
import tweepy
from datetime import date, datetime, timedelta
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tweepy
import json

from config import consumer_key, consumer_secret, access_token, access_token_secret
from pprint import pprint

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Twitter API Keys
consumer_key = consumer_key
consumer_secret = consumer_secret
access_token = access_token
access_token_secret = access_token_secret

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %% [markdown]
# ### Test 1. Count 100 no matter when the article created

# %%
media_df = pd.DataFrame({
    "Media": [],
    "Date": [],
    "Text": [],
    "Compound": [],
    "Positive": [],
    "Negative": [],
    "Neutral": []    
})
media_df
# Out:
# Empty DataFrame
# Columns: [Compound, Date, Media, Negative, Neutral, Positive, Text]
# Index: []

# %%
target_media = ["@BBC", "@CBSNews", "@CNN", "@Fox", "@nytimes"]

# %%
# Set index with a variable 'counter'
counter = 1

# Grab 25 tweets
for target_term in target_media:
    public_tweets = api.user_timeline(target_term, count=100)
    
    # Loop through all tweets
    for tweet in public_tweets:

        # Create a row by adding media name
        media_df.loc[counter, "Media"] = target_term

        # Add Tweet text
        media_df.loc[counter, "Text"] = tweet["text"]

        # Add Date
        media_df.loc[counter, "Date"] = tweet["created_at"]

        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])

        # Add each value to the appropriate array
        media_df.loc[counter, "Compound"] = results["compound"]
        media_df.loc[counter, "Negative"] = results["neg"]
        media_df.loc[counter, "Positive"] = results["pos"]
        media_df.loc[counter, "Neutral"] = results["neu"]

        # Add row
        counter += 1

# %%
media_df = media_df[["Media", "Date", "Text", "Compound", "Positive", "Negative", "Neutral"]]
media_df
# Out:
#         Media                            Date  \
# 1        @BBC  Mon Jun 11 16:00:11 +0000 2018
# 2        @BBC  Mon Jun 11 15:18:53 +0000 2018
# 3        @BBC  Mon Jun 11 15:11:47 +0000 2018
# 4        @BBC  Mon Jun 11 15:03:32 +0000 2018
# 5        @BBC  Mon Jun 11 14:25:15 +0000 2018
# 6        @BBC  Mon Jun 11 13:03:03 +0000 2018
# 7        @BBC  Mon Jun 11 12:01:04 +0000 2018
# 8        @BBC  Mon Jun 11 11:03:13 +0000 2018
# 482  RT @nytimesarts: Andrew Garfield, after winnin...    0.8885     0.382
# 483  Students from Marjory Stoneman Douglas High Sc...    0.0000     0.000
# 484  “All the goodness and tragedy that has brought...   -0.3400     0.114
# 485  Here's a full (and updating) list of the 2018 ...    0.7650     0.398
# 486  The National Puerto Rican Day Parade took on a...   -0.4404     0.000
# 487  The Tony Awards are underway. Follow our live ...    0.2023     0.135
# 488  Laurie Metcalf has been compared to a unicorn,...    0.1531     0.096
# 489  Now updated with Trump's insults of Trudeau, a...   -0.1779     0.117
# 490  Andrew Garfield just won a Tony Award for his ...    0.8020     0.298
# 491  Here's who we think will win the Tony Awards (...    0.7783     0.405
# 492  Bruce Springsteen is getting a special Tony Aw...    0.7351     0.360
# 493  RT @hellerNYT: John Leguizamo accepts his spec...    0.9495     0.511
# 494  A handful of shows have emerged as clear indus...    0.8126     0.412
# 495  She wanted to celebrate their marriage in lavi...    0.2732     0.152
# 496  News analysis: "With a petulant tweetstorm fro...    0.0000     0.000
# 497  In a small study, doctors used so-called fecal...    0.3400     0.135
# 498  "Sex and the City" spurred a generation of you...    0.4767     0.162
# 499  RT @nytimesarts: It was the year of the big br...    0.0000     0.000
# 500  Republican Party consultants say their polling...    0.6597     0.252
#
#      Negative  Neutral
# 1       0.000    0.696
# 2       0.075    0.711
# 3       0.000    0.602
# 4       0.079    0.921
# 5       0.000    0.905
# 6       0.151    0.733
# 7       0.000    0.663
# 8       0.000    0.786
# 9       0.000    0.888
# 10      0.000    0.837
# 11      0.000    0.602
# 12      0.000    0.948
# 13      0.000    0.854
# 14      0.239    0.761
# 15      0.000    0.880
# 16      0.000    1.000
# 17      0.000    1.000
# 18      0.000    0.804
# 19      0.000    0.799
# 20      0.245    0.755
# 21      0.000    1.000
# 22      0.000    0.861
# 23      0.000    0.861
# 24      0.000    1.000
# 25      0.000    1.000
# 26      0.120    0.880
# 27      0.000    0.861
# 28      0.227    0.625
# 29      0.000    1.000
# 30      0.000    1.000
# ..        ...      ...
# 471     0.000    0.868
# 472     0.000    0.412
# 473     0.120    0.812
# 474     0.000    1.000
# 475     0.106    0.636
# 476     0.227    0.773
# 477     0.000    0.566
# 478     0.000    0.667
# 479     0.264    0.736
# 480     0.000    0.904
# 481     0.000    1.000
# 482     0.000    0.618
# 483     0.000    1.000
# 484     0.167    0.720
# 485     0.000    0.602
# 486     0.187    0.813
# 487     0.099    0.766
# 488     0.000    0.904
# 489     0.156    0.726
# 490     0.000    0.702
# 491     0.000    0.595
# 492     0.000    0.640
# 493     0.000    0.489
# 494     0.000    0.588
# 495     0.107    0.741
# 496     0.000    1.000
# 497     0.065    0.800
# 498     0.000    0.838
# 499     0.000    1.000
# 500     0.000    0.748
#
# [500 rows x 7 columns]

# %%
# Convert Date to Tweet Ago

tweeted_ago = []
for date in media_df["Date"]:
    tweeted_time = datetime.datetime.strptime(date, "%a %b %d %H:%M:%S +0000 %Y")
    day_difference = datetime.datetime(2018, 6, 12) - tweeted_time
    tweeted_ago.append(day_difference.days)

media_df["Date"] = tweeted_ago

# %%
color = []
for media in media_df["Media"]:
    if media == "@BBC":
        color.append("Red")
    elif media == "@CBSNews":
        color.append("Orange")
    elif media == "@CNN":
        color.append("Yellow")
    elif media == "@Fox": 
        color.append("Purple")
    else:
        color.append("Green")

media_df["Color"] = color

# %%
plt.scatter(media_df["Date"], media_df["Compound"], c = media_df["Color"], cmap="jet")
plt.show()

# %%
media_df_grouped = media_df.groupby("Media")["Compound"].mean()
media_df_grouped
# Out:
# Media
# @BBC        0.177656
# @CBSNews    0.064537
# @CNN       -0.086987
# @Fox        0.257156
# @nytimes    0.126849
# Name: Compound, dtype: float64

# %%
media_df_grouped.plot(kind="bar")

# %% [markdown]
# ### Test 2. Count articles after 12 hrs from the last article

# %%
media_daily_df = pd.DataFrame({
    "Media": [],
    "Date": [],
    "Text": [],
    "Compound": [],
    "Positive": [],
    "Negative": [],
    "Neutral": []    
})
media_daily_df
# Out:
# Empty DataFrame
# Columns: [Compound, Date, Media, Negative, Neutral, Positive, Text]
# Index: []

# %%
target_media = ["@BBC", "@CBSNews", "@CNN", "@Fox", "@nytimes"]

# %%
# Set index with a variable 'counter'
counter = 1

# Grab 25 tweets
for target_term in target_media:
    public_tweets = api.user_timeline(target_term, count=1000)
    latest_tweet = public_tweets[0]["created_at"]
    latest_date = datetime.datetime.strptime(latest_tweet, "%a %b %d %H:%M:%S +0000 %Y")
    
    # Loop through all tweets
    for tweet in public_tweets:
        
        day = tweet["created_at"]
        tweet_date = datetime.datetime.strptime(day, "%a %b %d %H:%M:%S +0000 %Y")
        
        if tweet_date < latest_date:
            # Create a row by adding media name
            media_daily_df.loc[counter, "Media"] = target_term

            # Add Tweet text
            media_daily_df.loc[counter, "Text"] = tweet["text"]

            # Add Date
            media_daily_df.loc[counter, "Date"] = tweet["created_at"]

            # Run Vader Analysis on each tweet
            results = analyzer.polarity_scores(tweet["text"])

            # Add each value to the appropriate array
            media_daily_df.loc[counter, "Compound"] = results["compound"]
            media_daily_df.loc[counter, "Negative"] = results["neg"]
            media_daily_df.loc[counter, "Positive"] = results["pos"]
            media_daily_df.loc[counter, "Neutral"] = results["neu"]

            # Add row
            counter += 1
            
            # subtract 1 day from latest_date
            latest_date -= timedelta(hours=12)

# %%
media_daily_df = media_daily_df[["Media", "Date", "Text", "Compound", "Positive", "Negative", "Neutral"]]
media_daily_df
# Out:
#        Media                            Date  \
# 1       @BBC  Sun Jun 10 18:02:27 +0000 2018
# 2       @BBC  Sun Jun 10 07:03:02 +0000 2018
# 3       @BBC  Sat Jun 09 19:02:05 +0000 2018
# 4       @BBC  Fri Jun 08 20:04:03 +0000 2018
# 5       @BBC  Fri Jun 08 18:09:05 +0000 2018
# 6       @BBC  Fri Jun 08 07:00:18 +0000 2018
# 7       @BBC  Thu Jun 07 18:00:21 +0000 2018
# 8       @BBC  Thu Jun 07 07:01:05 +0000 2018
# 9       @BBC  Wed Jun 06 19:03:03 +0000 2018
# 10      @BBC  Wed Jun 06 07:04:04 +0000 2018
# 11      @BBC  Tue Jun 05 19:02:05 +0000 2018
# 12      @BBC  Tue Jun 05 07:00:11 +0000 2018
# 13      @BBC  Mon Jun 04 19:03:02 +0000 2018
# 14      @BBC  Mon Jun 04 07:00:15 +0000 2018
# 65  RT @andyet: We’re super lucky in having both a...    0.7717     0.242
# 66  @sodevious Yeah, most conferences are targeted...    0.2960     0.136
# 67  @joasqueeniebee I haven’t seen good front-end ...    0.3818     0.285
# 68  RT @_ElizabethMay: Hi ladies!\n\nRT if you've ...   -0.7777     0.000
# 69  @jennschiffer this made me think of you https:...    0.0000     0.000
# 70  RT @sarah_federman: Hi, male presenters. Your ...   -0.4031     0.101
# 71  How our attitudes to our teeth have transforme...    0.0000     0.000
# 72  In Opinion\n\nOp-Ed contributor Laurence Maslo...    0.0000     0.000
# 73  RT @NYTSports: After losing to Simona Halep in...    0.2732     0.136
# 74  In his own unorthodox way, Trump has been prep...    0.0000     0.000
#
#     Negative  Neutral
# 1      0.000    0.880
# 2      0.067    0.491
# 3      0.000    0.878
# 4      0.000    1.000
# 5      0.000    0.617
# 6      0.000    1.000
# 7      0.000    1.000
# 8      0.000    0.732
# 9      0.000    1.000
# 10     0.000    1.000
# 11     0.273    0.727
# 12     0.000    1.000
# 13     0.178    0.822
# 14     0.119    0.715
# 15     0.000    0.867
# 16     0.000    1.000
# 17     0.000    0.833
# 18     0.000    1.000
# 19     0.000    1.000
# 20     0.198    0.496
# 21     0.266    0.734
# 22     0.000    0.759
# 23     0.331    0.669
# 24     0.113    0.887
# 25     0.087    0.827
# 26     0.264    0.736
# 27     0.000    0.761
# 28     0.110    0.890
# 29     0.286    0.714
# 30     0.000    0.942
# ..       ...      ...
# 45     0.000    0.942
# 46     0.000    1.000
# 47     0.000    0.715
# 48     0.000    0.637
# 49     0.000    0.894
# 50     0.065    0.935
# 51     0.000    0.690
# 52     0.000    1.000
# 53     0.000    1.000
# 54     0.000    0.825
# 55     0.000    1.000
# 56     0.000    1.000
# 57     0.270    0.730
# 58     0.000    0.541
# 59     0.000    1.000
# 60     0.116    0.884
# 61     0.000    1.000
# 62     0.000    1.000
# 63     0.000    0.696
# 64     0.000    0.811
# 65     0.000    0.758
# 66     0.000    0.864
# 67     0.100    0.615
# 68     0.274    0.726
# 69     0.000    1.000
# 70     0.192    0.707
# 71     0.000    1.000
# 72     0.000    1.000
# 73     0.095    0.769
# 74     0.000    1.000
#
# [74 rows x 7 columns]

# %%
# Convert Date to Tweet Ago

tweeted_ago = []
for date in media_daily_df["Date"]:
    tweeted_time = datetime.datetime.strptime(date, "%a %b %d %H:%M:%S +0000 %Y")
    tweeted_ago.append(tweeted_time)

tweeted_ago
# Out:
# [datetime.datetime(2018, 6, 10, 18, 2, 27),
#  datetime.datetime(2018, 6, 10, 7, 3, 2),
#  datetime.datetime(2018, 6, 9, 19, 2, 5),
#  datetime.datetime(2018, 6, 8, 20, 4, 3),
#  datetime.datetime(2018, 6, 8, 18, 9, 5),
#  datetime.datetime(2018, 6, 8, 7, 0, 18),
#  datetime.datetime(2018, 6, 7, 18, 0, 21),
#  datetime.datetime(2018, 6, 7, 7, 1, 5),
#  datetime.datetime(2018, 6, 6, 19, 3, 3),
#  datetime.datetime(2018, 6, 6, 7, 4, 4),
#  datetime.datetime(2018, 6, 5, 19, 2, 5),
#  datetime.datetime(2018, 6, 5, 7, 0, 11),
#  datetime.datetime(2018, 6, 4, 19, 3, 2),
#  datetime.datetime(2018, 6, 4, 7, 0, 15),
#  datetime.datetime(2018, 6, 3, 19, 2, 6),
#  datetime.datetime(2018, 6, 3, 7, 4, 3),
#  datetime.datetime(2018, 6, 2, 19, 2, 5),
#  datetime.datetime(2018, 6, 1, 19, 6, 4),
#  datetime.datetime(2018, 6, 1, 18, 1, 7),
#  datetime.datetime(2018, 6, 1, 7, 0, 15),
#  datetime.datetime(2018, 5, 31, 19, 2, 2),
#  datetime.datetime(2018, 5, 30, 19, 2, 5),
#  datetime.datetime(2018, 5, 30, 18, 3, 4),
#  datetime.datetime(2018, 6, 11, 5, 46, 37),
#  datetime.datetime(2018, 6, 10, 18, 0, 14),
#  datetime.datetime(2018, 6, 10, 6, 18, 5),
#  datetime.datetime(2018, 6, 9, 18, 14, 56),
#  datetime.datetime(2018, 6, 11, 5, 30, 10),
#  datetime.datetime(2018, 6, 10, 18, 0, 4),
#  datetime.datetime(2018, 6, 10, 6, 1, 7),
#  datetime.datetime(2018, 6, 9, 18, 0, 6),
#  datetime.datetime(2018, 6, 9, 10, 36, 55),
#  datetime.datetime(2018, 6, 8, 19, 36, 53),
#  datetime.datetime(2018, 6, 8, 10, 43, 28),
#  datetime.datetime(2018, 6, 7, 20, 51, 50),
#  datetime.datetime(2018, 6, 7, 10, 10, 4),
#  datetime.datetime(2018, 6, 6, 18, 46, 56),
#  datetime.datetime(2018, 6, 6, 9, 5, 55),
#  datetime.datetime(2018, 6, 5, 19, 13, 37),
#  datetime.datetime(2018, 6, 5, 9, 21, 52),
#  datetime.datetime(2018, 6, 4, 19, 54, 12),
#  datetime.datetime(2018, 6, 3, 13, 35, 22),
#  datetime.datetime(2018, 6, 3, 13, 27, 20),
#  datetime.datetime(2018, 6, 3, 10, 40, 49),
#  datetime.datetime(2018, 6, 2, 9, 4, 2),
#  datetime.datetime(2018, 6, 2, 9, 2, 54),
#  datetime.datetime(2018, 6, 1, 8, 58, 9),
#  datetime.datetime(2018, 5, 31, 15, 51, 8),
#  datetime.datetime(2018, 5, 31, 14, 23, 46),
#  datetime.datetime(2018, 5, 31, 10, 49, 36),
#  datetime.datetime(2018, 5, 30, 12, 39, 27),
#  datetime.datetime(2018, 5, 30, 2, 42, 33),
#  datetime.datetime(2018, 5, 29, 11, 20, 52),
#  datetime.datetime(2018, 5, 29, 7, 33, 39),
#  datetime.datetime(2018, 5, 28, 22, 8, 5),
#  datetime.datetime(2018, 5, 28, 10, 53, 34),
#  datetime.datetime(2018, 5, 26, 10, 10, 37),
#  datetime.datetime(2018, 5, 25, 7, 1, 39),
#  datetime.datetime(2018, 5, 25, 6, 57, 57),
#  datetime.datetime(2018, 5, 25, 5, 51, 21),
#  datetime.datetime(2018, 5, 25, 5, 21, 19),
#  datetime.datetime(2018, 5, 25, 4, 22, 42),
#  datetime.datetime(2018, 5, 24, 22, 5, 56),
#  datetime.datetime(2018, 5, 24, 10, 16, 27),
#  datetime.datetime(2018, 5, 23, 22, 58, 23),
#  datetime.datetime(2018, 5, 23, 11, 28, 30),
#  datetime.datetime(2018, 5, 22, 22, 55, 7),
#  datetime.datetime(2018, 5, 22, 10, 53, 2),
#  datetime.datetime(2018, 5, 21, 22, 34, 28),
#  datetime.datetime(2018, 5, 21, 10, 39),
#  datetime.datetime(2018, 6, 11, 6, 2, 7),
#  datetime.datetime(2018, 6, 10, 18, 15, 4),
#  datetime.datetime(2018, 6, 10, 6, 7, 51),
#  datetime.datetime(2018, 6, 9, 18, 15, 8)]

# %%
color = []
for media in media_daily_df["Media"]:
    if media == "@BBC":
        color.append("Red")
    elif media == "@CBSNews":
        color.append("Orange")
    elif media == "@CNN":
        color.append("Yellow")
    elif media == "@Fox": 
        color.append("Purple")
    else:
        color.append("Green")

media_daily_df["Color"] = color
media_daily_df
# Out:
# c:\users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        Media                            Date  \
# 1       @BBC  Sun Jun 10 18:02:27 +0000 2018
# 2       @BBC  Sun Jun 10 07:03:02 +0000 2018
# 3       @BBC  Sat Jun 09 19:02:05 +0000 2018
# 4       @BBC  Fri Jun 08 20:04:03 +0000 2018
# 5       @BBC  Fri Jun 08 18:09:05 +0000 2018
# 6       @BBC  Fri Jun 08 07:00:18 +0000 2018
# 7       @BBC  Thu Jun 07 18:00:21 +0000 2018
# 8       @BBC  Thu Jun 07 07:01:05 +0000 2018
# 9       @BBC  Wed Jun 06 19:03:03 +0000 2018
# 10      @BBC  Wed Jun 06 07:04:04 +0000 2018
# 11      @BBC  Tue Jun 05 19:02:05 +0000 2018
# 12      @BBC  Tue Jun 05 07:00:11 +0000 2018
# 13      @BBC  Mon Jun 04 19:03:02 +0000 2018
# 14      @BBC  Mon Jun 04 07:00:15 +0000 2018
# 15      @BBC  Sun Jun 03 19:02:06 +0000 2018
# 16      @BBC  Sun Jun 03 07:04:03 +0000 2018
# 17      @BBC  Sat Jun 02 19:02:05 +0000 2018
# 18      @BBC  Fri Jun 01 19:06:04 +0000 2018
# 19      @BBC  Fri Jun 01 18:01:07 +0000 2018
# 20      @BBC  Fri Jun 01 07:00:15 +0000 2018
# 21      @BBC  Thu May 31 19:02:02 +0000 2018
# 22      @BBC  Wed May 30 19:02:05 +0000 2018
# 23      @BBC  Wed May 30 18:03:04 +0000 2018
# 24  @CBSNews  Mon Jun 11 05:46:37 +0000 2018
# 25  @CBSNews  Sun Jun 10 18:00:14 +0000 2018
# 26  @CBSNews  Sun Jun 10 06:18:05 +0000 2018
# 27  @CBSNews  Sat Jun 09 18:14:56 +0000 2018
# 28      @CNN  Mon Jun 11 05:30:10 +0000 2018
# 29      @CNN  Sun Jun 10 18:00:04 +0000 2018
# 30      @CNN  Sun Jun 10 06:01:07 +0000 2018
# ..       ...                             ...
# 45      @Fox  Sat Jun 02 09:04:02 +0000 2018
# 46      @Fox  Sat Jun 02 09:02:54 +0000 2018
# 47      @Fox  Fri Jun 01 08:58:09 +0000 2018
# 48      @Fox  Thu May 31 15:51:08 +0000 2018
# 49      @Fox  Thu May 31 14:23:46 +0000 2018
# 50      @Fox  Thu May 31 10:49:36 +0000 2018
# 51      @Fox  Wed May 30 12:39:27 +0000 2018
# 52      @Fox  Wed May 30 02:42:33 +0000 2018
# 53      @Fox  Tue May 29 11:20:52 +0000 2018
# 54      @Fox  Tue May 29 07:33:39 +0000 2018
# 55      @Fox  Mon May 28 22:08:05 +0000 2018
# 56      @Fox  Mon May 28 10:53:34 +0000 2018
# 57      @Fox  Sat May 26 10:10:37 +0000 2018
# 58      @Fox  Fri May 25 07:01:39 +0000 2018
# 59      @Fox  Fri May 25 06:57:57 +0000 2018
# 60      @Fox  Fri May 25 05:51:21 +0000 2018
# 61      @Fox  Fri May 25 05:21:19 +0000 2018
# 62      @Fox  Fri May 25 04:22:42 +0000 2018
# 63      @Fox  Thu May 24 22:05:56 +0000 2018
# 64      @Fox  Thu May 24 10:16:27 +0000 2018
# 65      @Fox  Wed May 23 22:58:23 +0000 2018
# 66      @Fox  Wed May 23 11:28:30 +0000 2018
# 67      @Fox  Tue May 22 22:55:07 +0000 2018
# 68      @Fox  Tue May 22 10:53:02 +0000 2018
# 69      @Fox  Mon May 21 22:34:28 +0000 2018
# 70      @Fox  Mon May 21 10:39:00 +0000 2018
# 71  @nytimes  Mon Jun 11 06:02:07 +0000 2018
# 72  @nytimes  Sun Jun 10 18:15:04 +0000 2018
# 73  @nytimes  Sun Jun 10 06:07:51 +0000 2018
# 74  @nytimes  Sat Jun 09 18:15:08 +0000 2018
#
#                                                  Text  Compound  Positive  \
# 1   Can we interest you in a little cockroach milk...    0.4588     0.120
# 2   This elderly man was struggling slowly across ...    0.9134     0.442
# 3   What is it like being Germaine Greer? This obs...    0.3612     0.122
# 4   🎶 Tonight, @ArcticMonkeys perform live for @BB...    0.0000     0.000
# 5   💃🕺 Why does dancing with our friends make us f...    0.7809     0.383
# 6   🌊💙 A message from Sir David Attenborough for #...    0.0000     0.000
# 7   ❤️️ Harry has been wearing a Spider-Man mask d...    0.0000     0.000
# 8   ❤️🐶 Some heroes don't wear capes - they wear c...    0.5106     0.268
# 9   Tonight, #OurGirl actress @michkeegan uncovers...    0.0000     0.000
# 10  📻🐫🦅🐼🦈 @GregJames has got a new co-host!\n\nSir...    0.0000     0.000
# 11  #OurGirl is back and heading to Nigeria in the...   -0.7184     0.000
# 12  💤 Ever wondered what your brain is up to while...    0.0000     0.000
# 13  Versailles is back! Tonight, Madame de Montesp...   -0.5707     0.000
# 14  📸🦊 This photographer captures foxes in their m...    0.2006     0.166
# 15  Comedian @frankieboyle is heading to Russia be...    0.3818     0.133
# 16  Remembering the people of Bunce Island, who we...    0.0000     0.000
# 17  A once-in-a-lifetime conversation with Eileen ...    0.4215     0.167
# 18  🎤❤️ #BTS are on the lips and screens of fans e...    0.0000     0.000
# 19       😈 Cute...but deadly. https://t.co/lhpd0watrN    0.0000     0.000
# 20  Is individualism to be celebrated or lamented?...    0.3182     0.306
# 21  'There's nothing a man can do that a woman can...   -0.7003     0.000
# 22  These cuddling baby hares are the cutest thing...    0.5859     0.241
# 23  Tonight, @DrJavidA and four overweight volunte...   -0.7845     0.000
# 24  A photo released by Germany depicting the tens...   -0.3182     0.000
# 25  With only $10 in his pocket and no prospect of...    0.0000     0.087
# 26  Report reveals Florida stopped doing gun permi...   -0.5106     0.000
# 27  The 2018 Belmont Stakes is set to take place t...    0.7650     0.239
# 28  A federal court temporarily blocked a pizza de...   -0.2732     0.000
# 29  An immigrant detained for illegally attempting...   -0.8020     0.000
# 30  Organic matter has been found on Mars in soil ...    0.0258     0.058
# ..                                                ...       ...       ...
# 45  I’m at #jsconfeu for the next two days. Come s...    0.0772     0.058
# 46  RT @misprintedtype: That opening... 😍😍😍 #jscon...    0.0000     0.000
# 47  @jackiebackwards thank you for the tweet quote...    0.7495     0.285
# 48  I’m happy products like @TransferWise pop up t...    0.8442     0.363
# 49  RT @KimCrayton1: I'd like to announce @patrici...    0.3612     0.106
# 50  RT @Katrina_HRM: The more often a woman said t...   -0.1027     0.000
# 51  @I3ekka I will be there, feel free to say hell...    0.5562     0.310
# 52                     @kriesse It’s been too long 💔💖    0.0000     0.000
# 53                  MEL ✈️ AUH ✈️ MUC ✈️ TXL\n\n😴😬😆😱👽    0.0000     0.000
# 54  @ZachACole Concierge is good too! I once had a...    0.4926     0.175
# 55  @torstenseemann I think so, it’s legendary. ht...    0.0000     0.000
# 56  Leaving for Europe tomorrow for a much needed ...    0.0000     0.000
# 57  RT @genderequityvic: Today, on #NationalSorryD...   -0.7430     0.000
# 58  I just rediscovered a list of my favorite trac...    0.9274     0.459
# 59                             @mjmichellekim So seen    0.0000     0.000
# 60  “Burnout isn’t something that goes away on its...   -0.4404     0.000
# 61  RT @emrazz: 1 in 4 women in your life have had...    0.0000     0.000
# 62  @superhighfives omg, Charlie, I thought it was...    0.0000     0.000
# 63  There are many details that factor into design...    0.7906     0.304
# 64  RT @ChloeCondon: Hey y’all, I want to be very ...    0.4927     0.189
# 65  RT @andyet: We’re super lucky in having both a...    0.7717     0.242
# 66  @sodevious Yeah, most conferences are targeted...    0.2960     0.136
# 67  @joasqueeniebee I haven’t seen good front-end ...    0.3818     0.285
# 68  RT @_ElizabethMay: Hi ladies!\n\nRT if you've ...   -0.7777     0.000
# 69  @jennschiffer this made me think of you https:...    0.0000     0.000
# 70  RT @sarah_federman: Hi, male presenters. Your ...   -0.4031     0.101
# 71  How our attitudes to our teeth have transforme...    0.0000     0.000
# 72  In Opinion\n\nOp-Ed contributor Laurence Maslo...    0.0000     0.000
# 73  RT @NYTSports: After losing to Simona Halep in...    0.2732     0.136
# 74  In his own unorthodox way, Trump has been prep...    0.0000     0.000
#
#     Negative  Neutral   Color
# 1      0.000    0.880     Red
# 2      0.067    0.491     Red
# 3      0.000    0.878     Red
# 4      0.000    1.000     Red
# 5      0.000    0.617     Red
# 6      0.000    1.000     Red
# 7      0.000    1.000     Red
# 8      0.000    0.732     Red
# 9      0.000    1.000     Red
# 10     0.000    1.000     Red
# 11     0.273    0.727     Red
# 12     0.000    1.000     Red
# 13     0.178    0.822     Red
# 14     0.119    0.715     Red
# 15     0.000    0.867     Red
# 16     0.000    1.000     Red
# 17     0.000    0.833     Red
# 18     0.000    1.000     Red
# 19     0.000    1.000     Red
# 20     0.198    0.496     Red
# 21     0.266    0.734     Red
# 22     0.000    0.759     Red
# 23     0.331    0.669     Red
# 24     0.113    0.887  Orange
# 25     0.087    0.827  Orange
# 26     0.264    0.736  Orange
# 27     0.000    0.761  Orange
# 28     0.110    0.890  Yellow
# 29     0.286    0.714  Yellow
# 30     0.000    0.942  Yellow
# ..       ...      ...     ...
# 45     0.000    0.942  Purple
# 46     0.000    1.000  Purple
# 47     0.000    0.715  Purple
# 48     0.000    0.637  Purple
# 49     0.000    0.894  Purple
# 50     0.065    0.935  Purple
# 51     0.000    0.690  Purple
# 52     0.000    1.000  Purple
# 53     0.000    1.000  Purple
# 54     0.000    0.825  Purple
# 55     0.000    1.000  Purple
# 56     0.000    1.000  Purple
# 57     0.270    0.730  Purple
# 58     0.000    0.541  Purple
# 59     0.000    1.000  Purple
# 60     0.116    0.884  Purple
# 61     0.000    1.000  Purple
# 62     0.000    1.000  Purple
# 63     0.000    0.696  Purple
# 64     0.000    0.811  Purple
# 65     0.000    0.758  Purple
# 66     0.000    0.864  Purple
# 67     0.100    0.615  Purple
# 68     0.274    0.726  Purple
# 69     0.000    1.000  Purple
# 70     0.192    0.707  Purple
# 71     0.000    1.000   Green
# 72     0.000    1.000   Green
# 73     0.095    0.769   Green
# 74     0.000    1.000   Green
#
# [74 rows x 8 columns]

# %%
plt.scatter(media_daily_df["Date"], media_daily_df["Compound"], c = media_daily_df["Color"], cmap="jet")

plt.show()

# %% [markdown]
# ### Test 3. Retrieve all tweets from a certain time - ???

# %%
media_month_df = pd.DataFrame({
    "Media": [],
    "Date": [],
    "Text": [],
    "Compound": [],
    "Positive": [],
    "Negative": [],
    "Neutral": []    
})
media_month_df
# Out:
# Empty DataFrame
# Columns: [Compound, Date, Media, Negative, Neutral, Positive, Text]
# Index: []

# %%
target_media = ["@BBC", "@CBSNews", "@CNN", "@Fox", "@nytimes"]

# %%
# Set index with a variable 'counter'
counter = 1

# Grab 25 tweets
for target_term in target_media:
    recent_tweet = api.user_timeline(target_term)
    latest_tweet = recent_tweet["created_at"]
    latest_date = datetime.datetime.strptime(latest_tweet, "%a %b %d %H:%M:%S +0000 %Y") 
    oldest_date = latest_date - timedelta(days=30)
    
    public_tweets = api.user_timeline(target_term, count=1000, since_id=)
    
    # Loop through all tweets
    for tweet in public_tweets:
        
        day = tweet["created_at"]
        tweet_date = datetime.datetime.strptime(day, "%a %b %d %H:%M:%S +0000 %Y")
        
        if tweet_date < latest_date:
            # Create a row by adding media name
            media_month_df.loc[counter, "Media"] = target_term

            # Add Tweet text
            media_month_df.loc[counter, "Text"] = tweet["text"]

            # Add Date
            media_month_df.loc[counter, "Date"] = tweet["created_at"]

            # Run Vader Analysis on each tweet
            results = analyzer.polarity_scores(tweet["text"])

            # Add each value to the appropriate array
            media_month_df.loc[counter, "Compound"] = results["compound"]
            media_month_df.loc[counter, "Negative"] = results["neg"]
            media_month_df.loc[counter, "Positive"] = results["pos"]
            media_month_df.loc[counter, "Neutral"] = results["neu"]

            # Add row
            counter += 1
            
            # subtract 1 day from latest_date
            latest_date -= timedelta(hours=12)

# %%
media_month_df = media_daily_df[["Media", "Date", "Text", "Compound", "Positive", "Negative", "Neutral"]]
media_month_df
